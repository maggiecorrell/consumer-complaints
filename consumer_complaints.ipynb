# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline

# %%
dec_complaints = pd.read_csv('complaints_dec_2014.csv')

# %%
dec_complaints
# Out:
#        Complaint ID                  Product  \
# 0           1177167          Debt collection
# 1           1177166          Debt collection
# 2           1177165          Debt collection
# 3           1177164          Debt collection
# 4           1177163          Debt collection
# 5           1177162          Debt collection
# 6           1177154              Credit card
# 7           1177143          Debt collection
# 8           1177140          Debt collection
# 9           1177139          Debt collection
# 10          1177136          Debt collection
# 11          1177128  Bank account or service
# 12          1177125          Debt collection
# 13          1177124          Debt collection
# 14          1177116          Debt collection
# 15          1177114          Debt collection
# 16          1177196         Credit reporting
# 17          1177113          Debt collection
# 18          1177112          Debt collection
# 19          1177101              Credit card
# ...

# %%
product = dec_complaints['Product'].value_counts()

# %%
product.plot(kind='bar', color = 'yellow')

# %%
company = dec_complaints['Company'].value_counts().head(10)

# %%
company.plot(kind='bar', color = 'limegreen')

# %%
company_response = dec_complaints['Company response'].value_counts()

# %%
company_response.plot(kind='bar', color = 'orange')

# %%
dec_complaints['day'] = pd.to_datetime(dec_complaints['Date received']).map(lambda d: d.weekday())
dec_complaints.groupby(['day', 'Date received']).size().groupby(level=0).mean().plot(color = 'gold')
